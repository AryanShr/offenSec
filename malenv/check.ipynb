# %%
import gym_malware as gm

# %%
import os

# %%
os.path.exists("RL_Features\\adversarial_imports_set.pk")
# Out:
# True

# %%
from gym_malware.envs.utils import interface, pefeatures

# %%
feature_extract = pefeatures.PEFeatureExtractor()

# %%
with open('hello.exe','rb') as f:
    byt = f.read()

# %%
feature_extract.extract(byt)
# Out:
# array([2.57712000e+05, 2.80673775e-01, 4.97609735e-02, 1.75389582e-02,
#        2.26803564e-02, 2.57031104e-02, 2.82563482e-02, 1.86797666e-02,
#        6.74008195e-03, 9.82104054e-03, 4.76500900e-03, 4.02387161e-03,
#        8.78888061e-03, 4.31489415e-03, 4.01223071e-03, 5.21512386e-03,
#        6.49174272e-03, 4.37309865e-03, 3.13916310e-03, 2.71621034e-03,
#        7.88089030e-03, 3.51943254e-03, 2.01775626e-03, 2.37086360e-03,
#        2.76665425e-03, 3.37198113e-03, 3.58151735e-03, 1.68017011e-03,
#        1.29990066e-03, 1.56376110e-03, 1.51331719e-03, 1.41242938e-03,
#        2.77441485e-03, 8.75395791e-03, 2.50667412e-03, 1.38526728e-03,
#        9.04110014e-04, 5.57211150e-03, 1.64912771e-03, 1.21841435e-03,
#        1.57540200e-03, 2.27385609e-03, 1.97507295e-03, 1.06320233e-03,
#        1.14080834e-03, 1.36198547e-03, 6.68575775e-03, 6.85649097e-03,
#        4.81545291e-03, 3.28273421e-03, 2.88694356e-03, 2.64248463e-03,
#        1.15632955e-03, 4.51278947e-03, 1.19125225e-03, 4.21788663e-03,
#        8.69187310e-04, 1.97119265e-03, 3.50391134e-03, 3.25169181e-03,
#        2.27385609e-03, 2.58816043e-03, 1.53271869e-03, 8.73067610e-04,
#        1.11752654e-03, 5.51002670e-03, 4.40414106e-03, 2.00999565e-03,
#        3.86477929e-03, 4.35757745e-03, 3.91522319e-03, 1.11364624e-03,
#        1.50555659e-03, 6.37145341e-03, 5.74284473e-03, 1.89746694e-03,
#        1.02439933e-03, 3.93074440e-03, 2.48339231e-03, 1.75001552e-03,
#        2.27385609e-03, 3.03051468e-03, 1.68017011e-03, 5.28108897e-03,
#        3.56211585e-03, 5.23840566e-03, 1.81598063e-03, 2.66188614e-03,
#        9.58434221e-04, 3.46898864e-03, 1.74613522e-03, 6.79052586e-04,
#        7.10094990e-04, 2.09148196e-03, 9.04110014e-04, 7.48897995e-04,
#        1.40272863e-02, 1.03992053e-03, 9.26615757e-03, 2.44846961e-03,
#        8.01282051e-03, 5.91745825e-03, 1.03875644e-02, 4.31101384e-03,
#        7.27168312e-03, 2.76277395e-03, 1.20250512e-02, 5.97566276e-04,
#        1.28825976e-03, 5.45182219e-03, 7.25228162e-03, 1.04806916e-02,
#        5.84761284e-03, 4.70680449e-03, 7.56658596e-04, 9.93356926e-03,
#        7.64419197e-03, 1.55638853e-02, 4.22564723e-03, 1.55212020e-03,
#        6.09983237e-03, 3.08095859e-03, 1.41242938e-03, 1.17185075e-03,
#        3.37586143e-04, 9.97237226e-04, 6.75172285e-04, 2.03327746e-03,
#        1.36974607e-03, 1.86254424e-03, 8.88588812e-04, 1.09036444e-03,
#        2.89082387e-03, 1.90134724e-03, 2.14580617e-03, 7.56658596e-04,
#        4.85037561e-04, 9.07990315e-04, 4.54771217e-03, 3.72508847e-04,
#        2.69292854e-03, 6.20848078e-04, 1.98283355e-03, 4.96678463e-04,
#        4.34593655e-04, 3.11976159e-03, 2.42518781e-03, 4.65636059e-04,
#        1.06320233e-03, 9.73955423e-04, 4.81157261e-04, 4.34593655e-04,
#        2.83261936e-04, 5.58763271e-04, 4.85037561e-04, 2.28937729e-04,
#        2.52219532e-04, 9.89476625e-04, 4.03551251e-04, 6.05326877e-04,
#        3.91910350e-03, 1.00111753e-03, 5.47122369e-04, 3.72508847e-04,
#        1.38138697e-03, 5.35481468e-04, 3.14304340e-04, 3.29825542e-04,
#        4.15192152e-04, 4.03551251e-04, 3.53107345e-04, 4.30713354e-04,
#        3.95790650e-04, 8.14863103e-04, 3.64748246e-04, 3.06543739e-04,
#        6.63531384e-04, 9.04110014e-04, 3.25945241e-04, 4.34593655e-04,
#        2.87142236e-04, 5.31601167e-04, 2.71621034e-04, 5.93685975e-04,
#        5.62643571e-04, 9.35152418e-04, 7.68299497e-04, 6.05326877e-04,
#        2.13416527e-04, 6.36369280e-04, 3.60867946e-04, 5.00558763e-04,
#        5.04439064e-04, 2.38638480e-03, 1.07484324e-03, 8.26504004e-04,
#        1.47839449e-03, 1.45899298e-03, 7.06214689e-04, 8.38144906e-04,
#        1.14856895e-03, 9.89476625e-04, 9.39032719e-04, 7.33376793e-04,
#        4.30713354e-04, 7.37257093e-04, 5.54882970e-04, 4.96678463e-04,
#        5.39361768e-04, 1.40078848e-03, 4.19072453e-04, 6.40249581e-04,
#        5.08319364e-04, 6.86813187e-04, 5.00558763e-04, 5.43242069e-04,
#        4.69516359e-04, 6.05326877e-04, 4.77276960e-04, 5.97566276e-04,
#        5.82045074e-04, 3.33705842e-04, 3.45346744e-04, 3.84149749e-04,
#        3.80269448e-04, 1.29602036e-03, 5.23840566e-04, 5.58763271e-04,
#        6.01446576e-04, 6.82932886e-04, 7.06214689e-04, 4.34593655e-04,
#        4.15192152e-04, 1.98283355e-03, 1.36974607e-03, 4.46234556e-04,
#        8.26504004e-04, 6.36369280e-04, 5.23840566e-04, 4.11311852e-04,
#        5.27720867e-04, 1.42795058e-03, 6.24728379e-04, 6.94573788e-04,
#        6.55770783e-04, 8.53666108e-04, 5.08319364e-04, 6.90693487e-04,
#        4.26833054e-04, 7.83820699e-04, 4.46234556e-04, 5.27720867e-04,
#        6.32488980e-04, 5.66523872e-04, 6.05326877e-04, 8.57546408e-04,
#        7.97013721e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.62500000e+03, 4.90000000e+01, 7.60000000e+01,
#        2.10000000e+01, 5.00000000e+01, 1.50000000e+01, 8.50000000e+01,
#        6.40000000e+01, 1.50000000e+01, 1.10000000e+01, 1.30000000e+01,
#        1.60000000e+01, 1.00000000e+01, 1.60000000e+01, 1.00000000e+01,
#        2.00000000e+01, 2.73210000e+04, 4.62000000e+02, 8.56000000e+02,
#        2.58000000e+02, 1.86000000e+02, 2.48000000e+02, 1.52000000e+03,
#        8.85000000e+02, 1.08000000e+02, 8.60000000e+01, 7.20000000e+01,
 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00])

# %%
from gym_malware.envs.utils.interface import EnsembleBlackBoxDetector

# %%
import os
import glob

# %%
path = "/media/nerdcoder/New Volume/Major Project/Pesiduos/Pesidious/Data/malware/*"

# %%
os.path.split(path)
# Out:
# ('/media/nerdcoder/New Volume/Major Project/Pesiduos/Pesidious/Data/malware',
#  '*')

# %%
glob.glob(path)
# Out:
# []

# %%
file_path = r"hello.exe"

# %%
with open(file_path,'rb') as f:
    bytt = f.read()

# %%
gm.interface.get_score_local(bytt)
# Out:
# 0.030372781679034233

# %%
# env2 = gm.envs.malenv.MalwareEnv(random_sample=False,output_path="/media/nerdcoder/New Volume/Major Project/malenv/modified")
env2 = gm.envs.malenv.MalwareEnv(random_sample=False,output_path="modified")

# %%
env2.action_space
# Out:
# Discrete(4)

# %%
a = env2.reset(file_path)
a
# Out:
# Already benign
# array([2.57712000e+05, 2.80673775e-01, 4.97609735e-02, 1.75389582e-02,
#        2.26803564e-02, 2.57031104e-02, 2.82563482e-02, 1.86797666e-02,
#        6.74008195e-03, 9.82104054e-03, 4.76500900e-03, 4.02387161e-03,
#        8.78888061e-03, 4.31489415e-03, 4.01223071e-03, 5.21512386e-03,
#        6.49174272e-03, 4.37309865e-03, 3.13916310e-03, 2.71621034e-03,
#        7.88089030e-03, 3.51943254e-03, 2.01775626e-03, 2.37086360e-03,
#        2.76665425e-03, 3.37198113e-03, 3.58151735e-03, 1.68017011e-03,
#        1.29990066e-03, 1.56376110e-03, 1.51331719e-03, 1.41242938e-03,
#        2.77441485e-03, 8.75395791e-03, 2.50667412e-03, 1.38526728e-03,
#        9.04110014e-04, 5.57211150e-03, 1.64912771e-03, 1.21841435e-03,
#        1.57540200e-03, 2.27385609e-03, 1.97507295e-03, 1.06320233e-03,
#        1.14080834e-03, 1.36198547e-03, 6.68575775e-03, 6.85649097e-03,
#        4.81545291e-03, 3.28273421e-03, 2.88694356e-03, 2.64248463e-03,
#        1.15632955e-03, 4.51278947e-03, 1.19125225e-03, 4.21788663e-03,
#        8.69187310e-04, 1.97119265e-03, 3.50391134e-03, 3.25169181e-03,
#        2.27385609e-03, 2.58816043e-03, 1.53271869e-03, 8.73067610e-04,
#        1.11752654e-03, 5.51002670e-03, 4.40414106e-03, 2.00999565e-03,
#        3.86477929e-03, 4.35757745e-03, 3.91522319e-03, 1.11364624e-03,
#        1.50555659e-03, 6.37145341e-03, 5.74284473e-03, 1.89746694e-03,
#        1.02439933e-03, 3.93074440e-03, 2.48339231e-03, 1.75001552e-03,
#        2.27385609e-03, 3.03051468e-03, 1.68017011e-03, 5.28108897e-03,
#        3.56211585e-03, 5.23840566e-03, 1.81598063e-03, 2.66188614e-03,
#        9.58434221e-04, 3.46898864e-03, 1.74613522e-03, 6.79052586e-04,
#        7.10094990e-04, 2.09148196e-03, 9.04110014e-04, 7.48897995e-04,
#        1.40272863e-02, 1.03992053e-03, 9.26615757e-03, 2.44846961e-03,
#        8.01282051e-03, 5.91745825e-03, 1.03875644e-02, 4.31101384e-03,
#        7.27168312e-03, 2.76277395e-03, 1.20250512e-02, 5.97566276e-04,
#        1.28825976e-03, 5.45182219e-03, 7.25228162e-03, 1.04806916e-02,
#        7.10000000e+01, 1.00000000e+02, 6.40000000e+01, 8.30000000e+01,
#        3.56000000e+02, 1.23940000e+04, 1.72700000e+03, 2.84600000e+03,
#        1.24000000e+03, 7.60300000e+03, 2.00400000e+03, 1.13900000e+03,
#        1.69300000e+03, 7.18700000e+03, 9.36000000e+02, 2.84000000e+02,
#        9.05000000e+02, 3.07700000e+03, 1.16300000e+03, 2.58600000e+03,
#        4.41600000e+03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00])

# %%
a.shape[0]
# Out:
# 513

# %%
import lief

# %%
a =lief.parse(byt)

# %%
type(a)
# Out:
# lief._lief.PE.Binary

# %%
lief.PE.Builder(a)

# %%
state,reward,done,action = env2.step(3)    
state,reward,done,action
# Out:
# lib name : oleaut32.dll , func name : SysAllocString
# <class 'lief._lief.PE.Binary'>
# Wrote file to modified\hello.exe
# (array([2.17600000e+05, 2.31263787e-01, 5.41865809e-02, 1.79090074e-02,
#         2.05698529e-02, 3.01654412e-02, 3.30606618e-02, 2.08593750e-02,
#         6.36029412e-03, 1.07582721e-02, 5.30790441e-03, 4.48069853e-03,
#         9.82536765e-03, 4.62775735e-03, 4.32444853e-03, 5.80422794e-03,
#         7.31158088e-03, 4.65073529e-03, 3.49264706e-03, 2.68382353e-03,
#         9.05330882e-03, 3.87408088e-03, 2.15992647e-03, 2.62408088e-03,
#         3.10202206e-03, 3.73621324e-03, 4.07628676e-03, 1.89797794e-03,
#         1.45220588e-03, 1.74172794e-03, 1.72334559e-03, 1.55330882e-03,
#         3.21231618e-03, 9.74724265e-03, 2.90441176e-03, 1.59007353e-03,
#         1.06617647e-03, 5.45955882e-03, 2.08180147e-03, 1.53033088e-03,
#         1.98069853e-03, 2.72977941e-03, 2.11397059e-03, 1.14430147e-03,
#         1.10294118e-03, 1.52113971e-03, 7.84466912e-03, 4.14522059e-03,
#         5.62959559e-03, 3.45588235e-03, 3.35477941e-03, 2.94117647e-03,
#         1.30055147e-03, 4.97242647e-03, 1.10753676e-03, 4.69209559e-03,
#         7.12316176e-04, 2.23805147e-03, 3.87408088e-03, 3.77297794e-03,
#         2.63327206e-03, 2.98713235e-03, 1.74172794e-03, 9.65073529e-04,
#         1.26838235e-03, 6.69117647e-03, 5.00000000e-03, 2.29319853e-03,
#         4.31066176e-03, 4.89430147e-03, 4.39338235e-03, 1.26838235e-03,
#         1.65900735e-03, 7.65625000e-03, 6.57628676e-03, 2.15073529e-03,
#         1.14889706e-03, 4.41176471e-03, 2.81709559e-03, 1.93933824e-03,
#         2.54595588e-03, 3.29503676e-03, 1.94393382e-03, 6.03860294e-03,
#         3.97058824e-03, 5.82720588e-03, 2.00827206e-03, 3.09283088e-03,
#         1.07996324e-03, 4.19577206e-03, 2.01746324e-03, 7.62867647e-04,
#         8.04227941e-04, 2.38051471e-03, 1.02481618e-03, 8.40992647e-04,
#         1.11397059e-02, 9.37500000e-04, 5.90533088e-03, 2.07720588e-03,
#         8.41911765e-03, 4.29687500e-03, 9.56341912e-03, 4.13143382e-03,
#         7.86305147e-03, 2.96875000e-03, 1.13924632e-02, 6.11213235e-04,
 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00]),
#  10.0,
#  True,
#  'imports_append')

# %%
import numpy as np

np.array_equal(state, prev)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 import numpy as np
# ----> 3 np.array_equal(state, prev)
#
# NameError: name 'prev' is not defined

# %%
prev = state

# %%
import numpy
numpy.__version__
# Out:
# '1.26.4'

# %%
env2.observation_space
# Out:
# array([2.08960000e+05, 2.45324464e-01, 1.19448698e-02, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
import pickle

# %%
a = pickle.load(open('/media/nerdcoder/New Volume/Major Project/malenv/gym_malware/envs/utils/feature_vector_mapping.pk','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a = pickle.load(open('/media/nerdcoder/New Volume/Major Project/malenv/gym_malware/envs/utils/feature_vector_mapping.pk','rb'))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/nerdcoder/New Volume/Major Project/malenv/gym_malware/envs/utils/feature_vector_mapping.pk'

# %%
b = pickle.load(open('/media/nerdcoder/New Volume/Major Project/malenv/RL_Features/adversarial_imports_set.pk','rb'))

# %%
b
# Out:
# {'cryptdll.dll': ['CDLocateRng'],
#  'kernel32.dll': ['CopyFileW',
#   'SetCurrentDirectoryA',
#   'CloseHandle',
#   'OpenMutexA',
#   'GetPrivateProfileStringA',
#   'CreateDirectoryW',
#   'GetLogicalDriveStringsW',
#   'GetTimeFormatA',
#   'CreateMutexW',
#   'CompareStringA',
#   'SetErrorMode',
#   'GetProcAddress',
#   'WriteProcessMemory',
#   'QueryDosDeviceA',
#   'lstrcpynA',
#   'GetCommandLineA',
#   'GetCurrentThreadId',
#   'GetCurrentThread',
#   'GetModuleHandleA',
#   'GetVolumeInformationW',
#   'OpenThread',
#   'VirtualAlloc',
#   'GetVersionExA',
#   'GetACP',
#   'LoadLibraryA',
#   'InitializeCriticalSection',
#   'RaiseException',
#   'GetLocaleInfoW',
#   'ExitProcess',
#   'HeapFree',
#   'QueryPerformanceCounter',
#   'GetTickCount',
#   'GetCurrentProcessId',
#   'GetSystemTimeAsFileTime',
#   'GetModuleFileNameA',
#   'GetLastError',
#   'WriteFile',
#   'GetCurrentProcess',
#   'HeapAlloc',
#   'FlushFileBuffers',
#   'SetUnhandledExceptionFilter',
#   'HeapDestroy',
#   'HeapCreate',
#   'IsBadWritePtr',
#   'VirtualQuery',
#   'UnhandledExceptionFilter',
#   'WideCharToMultiByte',
#   'GetEnvironmentStringsW',
#   'SetHandleCount',
#   'IsBadReadPtr',
#   'IsBadCodePtr',
#   'ReadFile',
#   'SetStdHandle',
#   'GetCPInfo',
#   'LCMapStringA',
#   'MultiByteToWideChar',
#   'LCMapStringW',
#   'VirtualProtect',
#   'GetUserDefaultLCID',
#   'EnumSystemLocalesA',
#   'IsValidCodePage',
#   'CreateFileA',
#   'FileTimeToSystemTime',
#   'ReadConsoleW',
#   'FindFirstFileA',
#   'DeviceIoControl',
#   'SetEnvironmentVariableW',
#   'CreateDirectoryA',
#   'GetCurrentDirectoryW',
#   'SleepEx',
#   'GetSystemDirectoryW',
#   'SetEvent',
#   'WaitForSingleObject',
#   'Sleep',
#   'GetTimeFormatW',
#   'ExpandEnvironmentStringsA',
#   'GetFileSize',
#   'GetSystemDirectoryA',
#   'GetTempPathA',
#   'GlobalMemoryStatus',
#   'CopyFileA',
#   'InterlockedIncrement',
#   'LocalAlloc',
#   'LocalFree',
#   'CreateProcessA',
#   'lstrlenA',
#   'CreateThread',
#   'DeleteFileA',
#   'GetModuleFileNameW',
#   'GetProcessHeap',
#   'GetCommandLineW',
#   'FreeLibrary',
#   'GetVersionExW',
#   'GlobalFindAtomA',
#   'GlobalAddAtomA',
#   'GetShortPathNameA',
#   'GetHandleInformation',
#   'SetPriorityClass',
#   'SetThreadPriority',
#   'GetFileSizeEx',
#   'SetFileAttributesA',
#   'GetTempFileNameA',
#   'SetCurrentDirectoryW',
#   'InterlockedExchangeAdd',
#   'GetExitCodeProcess',
#   'GetTempPathW',
#   'CopyFileExA',
#   'GetLongPathNameA',
#   'GetFileAttributesA',
#   'ReleaseMutex',
#   'lstrcatA',
#   'FindNextFileA',
#   'FindNextFileW',
#   'GetNumberFormatW',
#   'MoveFileExW',
#   'UnmapViewOfFile',
#   'CreateFileMappingW',
#   'SystemTimeToFileTime',
#   'IsDBCSLeadByte',
#   'LoadLibraryW',
#   'GetFileAttributesW',
#   'SetFileTime',
#   'DosDateTimeToFileTime',
#   'EnterCriticalSection',
#   'GetVolumeInformationA',
#   'MoveFileExA',
#   'UnlockFile',
#   'LockFile',
#   'HeapValidate',
#   'FlushInstructionCache',
#   'CreateRemoteThread',
#   'VirtualAllocEx',
#   'GlobalReAlloc',
#   'GetConsoleCP',
#   'GetStartupInfoW',
#   'DecodePointer',
#   'IsProcessorFeaturePresent',
#   'TlsAlloc',
#   'FatalAppExitA',
#   'AddAtomW',
#   'FreeConsole',
#   'GetTempFileNameW',
#   'SetLocaleInfoW',
#   'EnumLanguageGroupLocalesW',
#   'GetPrivateProfileSectionNamesA',
#   'SetConsoleTitleA',
#   'GetVolumePathNameA',
#   'GetProfileIntA',
#   'GetDateFormatA',
#   'DebugBreak',
#   'SuspendThread',
#   'MoveFileWithProgressA',
#   'GetNumberOfConsoleInputEvents',
#   'WritePrivateProfileStructA',
#   'SetComputerNameExA',
#   'FormatMessageA',
#   'RemoveDirectoryA',
#   'GetPrivateProfileIntA',
#   'CreateFileMappingA',
#   'PeekNamedPipe',
#   'GetTimeZoneInformation',
#   'GlobalFree',
#   'CreateProcessW',
#   'OpenFileMappingA',
#   'lstrcmp',
#   'ReadConsoleA',
#   'ReplaceFileA',
#   'CreateSemaphoreW',
#   'EnumSystemGeoID',
#   'EnumResourceTypesA',
#   'SetFilePointerEx',
#   'FindFirstFileExA',
#   'SetWaitableTimer',
#   'GetModuleHandleExW',
#   'LoadLibraryExW',
#   'WaitForSingleObjectEx',
#   'ResetEvent',
#   'OutputDebugStringW',
#   'GetComputerNameW',
#   'GetThreadLocale',
#   'lstrlen',
#   'lstrcpyW',
#   'SetLocaleInfoA',
#   'OpenFile',
#   'GlobalDeleteAtom',
#   'lstrcmpiW',
#   'DefineDosDeviceA',
#   'lstrcpy',
#   'FormatMessageW',
#   'GetLongPathNameW',
#   'QueueUserAPC',
#   'VirtualQueryEx',
#   'CancelIo',
#   'ClearCommBreak',
#   'BackupWrite',
#   'GetConsoleCursorInfo'],
#  'uxtheme.dll': ['GetThemeTextExtent',
#   'OpenThemeData',
#   'GetThemeFont',
#   'HitTestThemeBackground',
#   'GetThemePartSize'],
#  'untfs.dll': ['Recover', 'FormatEx'],
#  'wtsapi32.dll': ['WTSQueryUserToken',
#   'WTSVirtualChannelPurgeInput',
#   'WTSEnumerateSessionsA',
#   'WTSSetUserConfigA',
#   'WTSVirtualChannelOpen',
#   'WTSLogoffSession',
#   'WTSVirtualChannelRead',
#   'WTSSetSessionInformationW',
#   'WTSVirtualChannelClose'],
#  'userenv.dll': ['FreeGPOListW'],
#  'ole32.dll': ['CoTaskMemAlloc',
#   'CoInitialize',
#   'CoUninitialize',
#   'CoInitializeEx',
#   'OleUninitialize',
#   'CoInitializeSecurity',
#   'CoDisconnectObject'],
#  'shell32.dll': ['ShellAboutA',
#   'SHGetFileInfoA',
#   'SHGetDesktopFolder',
#   'ShellMessageBoxW',
#   'SHGetFolderPathA',
#   'DragFinish',
#   'ShellExecuteA',
#   'ShellAboutW',
#   'ShellExecuteExW',
#   'ShellExecuteExA',
#   'SHGetFolderPathW',
#   'SHGetDataFromIDListW',
#   'SHFree',
#   'SHGetNewLinkInfoA',
#   'SHDefExtractIconA',
#   'StrChrIA',
#   'SHChangeNotify',
#   'SHFileOperationW',
#   'SHGetSpecialFolderLocation',
#   'SHGetPathFromIDListW',
#   'ExtractIconW',
#   'SHGetSpecialFolderPathW',
#   'ExtractAssociatedIconExW',
#   'ShellHookProc',
#   'SHGetSpecialFolderPathA'],
#  'user32.dll': ['GetWindowRect',
#   'UpdateWindow',
#   'GetClientRect',
#   'SetTimer',
#   'GetSysColorBrush',
#   'IsIconic',
#   'OffsetRect',
#   'GetWindowTextA',
#   'GetWindow',
#   'SetFocus',
#   'GetForegroundWindow',
#   'LoadCursorA',
#   'LoadIconA',
#   'GetMessageA',
#   'SetWindowLongA',
#   'GetThreadDesktop',
#   'TranslateMessage',
#   'DispatchMessageA',
#   'SendMessageA',
#   'PostQuitMessage',
#   'ShowWindow',
#   'CreateWindowExA',
#   'DestroyWindow',
#   'MoveWindow',
#   'DefWindowProcA',
#   'CallWindowProcA',
#   'wsprintfW',
#   'RegisterClassExA',
#   'KillTimer',
#   'FlashWindow',
#   'PostMessageW',
#   'wsprintfA',
#   'GetKeyState',
#   'DrawTextW',
#   'MessageBoxExW',
#   'wvsprintfW',
#   'SendMessageW',
#   'SendDlgItemMessageW',
#   'WaitForInputIdle',
#   'SetForegroundWindow',
#   'GetSysColor',
#   'CharToOemA',
#   'GetParent',
#   'CreateWindowExW',
#   'SetWindowTextW',
#   'RegisterClassExW',
#   'DefWindowProcW',
#   'PeekMessageW',
#   'GetMessageW',
#   'CharToOemBuffW',
#   'GetDlgItem',
#   'OemToCharBuffA',
#   'CharUpperA',
#   'CharToOemBuffA',
#   'GetWindowTextW',
#   'CharUpperW',
#   'CopyRect',
#   'IntersectRect',
#   'SetCapture',
#   'GetMenu',
#   'PtInRect',
#   'InvalidateRect',
#   'GetCapture',
#   'EnableMenuItem',
#   'EndPaint',
#   'LoadStringA',
#   'LoadAcceleratorsA',
#   'SetCursor',
#   'PeekMessageA',
#   'SetDlgItemTextA',
#   'GetQueueStatus',
#   'CreateMenu',
#   'CreateAcceleratorTableA',
#   'GetMenuState',
#   'GetWindowWord',
#   'DefMDIChildProcA',
#   'SetWindowTextA',
#   'FindWindowW',
#   'RegisterWindowMessageW',
#   'MonitorFromRect',
#   'GetMonitorInfoA',
#   'GetWindowDC',
#   'CreateDialogParamA',
#   'OpenDesktopW',
#   'EnumChildWindows',
#   'SetScrollPos',
#   'SetWindowPlacement',
#   'SetWindowsHookExA',
#   'ShowCursor',
#   'ShowScrollBar',
#   'TranslateMDISysAccel',
#   'WinHelpA',
#   'OpenClipboard',
#   'MessageBeep',
#   'InSendMessage',
#   'GetWindowPlacement',
#   'GetScrollRange',
#   'GetScrollPos',
#   'GetMessageTime',
#   'GetMenuStringA',
#   'GetDlgCtrlID',
#   'GetDesktopWindow',
#   'FrameRect',
#   'EnumDesktopsA',
#   'EmptyClipboard',
#   'DrawMenuBar',
#   'DestroyCursor',
#   'DdeUninitialize',
#   'DdeSetUserHandle',
#   'DdeQueryConvInfo',
#   'DdeInitializeA',
#   'DdeGetLastError',
#   'DdeGetData',
#   'DdeFreeDataHandle',
#   'DdeDisconnect',
#   'DdeCreateStringHandleA',
#   'DdeClientTransaction',
#   'CountClipboardFormats',
#   'CloseClipboard',
#   'CheckDlgButton',
#   'AdjustWindowRectEx',
#   'SetDoubleClickTime',
#   'RegisterClipboardFormatA',
#   'IsDlgButtonChecked',
#   'DrawStateW',
#   'InsertMenuW',
#   'GetClassLongA'],
#  'comdlg32.dll': ['CommDlgExtendedError',
#   'GetSaveFileNameW',
#   'GetSaveFileNameA'],
#  'advapi32.dll': ['AdjustTokenPrivileges',
#   'RegCloseKey',
#   'RegOpenKeyExW',
#   'OpenProcessToken',
#   'RegCreateKeyExA',
#   'RegOpenKeyExA',
#   'RegQueryValueExA',
#   'RegSetValueExA',
#   'SetSecurityInfo',
#   'CryptGetHashParam',
#   'CryptAcquireContextA',
#   'CryptCreateHash',
#   'CryptDestroyHash',
#   'CryptHashData',
#   'GetSidSubAuthority',
#   'GetSidSubAuthorityCount',
#   'GetTokenInformation',
#   'RegCreateKeyA',
#   'RegDeleteValueA',
#   'RegFlushKey',
#   'CryptReleaseContext',
#   'LookupAccountSidW',
#   'SetFileSecurityA',
#   'SetThreadToken',
#   'GetSecurityDescriptorLength',
#   'CreateProcessAsUserA',
#   'IsValidSid',
#   'IsValidSecurityDescriptor',
#   'LookupAccountNameW',
#   'RegEnumKeyW',
#   'RegDeleteKeyA',
#   'RegSetValueA',
#   'SetSecurityDescriptorOwner',
#   'CopySid',
#   'StartServiceA',
#   'CreateProcessAsUserW',
#   'RegQueryInfoKeyW',
#   'MakeAbsoluteSD',
#   'GetFileSecurityW',
#   'RegisterServiceCtrlHandlerW',
#   'OpenThreadToken',
#   'GetLengthSid',
#   'DecryptFileW',
#   'SetNamedSecurityInfoW',
#   'LookupPrivilegeValueA',
#   'CloseServiceHandle',
#   'AllocateAndInitializeSid',
#   'RegCreateKeyW',
#   'RegUnLoadKeyW',
#   'RegisterServiceCtrlHandlerA',
#   'ReportEventW',
#   'SetKernelObjectSecurity',
#   'OpenSCManagerA',
#   'SetSecurityDescriptorGroup',
#   'SetServiceObjectSecurity',
#   'RegOpenKeyA',
#   'AddAccessAllowedAce'],
#  'version.dll': ['GetFileVersionInfoSizeW',
#   'GetFileVersionInfoW',
#   'VerQueryValueW'],
#  'msvcrt.dll': ['fflush',
#   'fclose',
#   'exit',
#   'fprintf',
#   'sprintf',
#   'wcsncmp',
#   'wcsncpy',
#   'wcsstr',
#   'wcstod',
#   'wcstol',
#   'memcpy',
#   'rand',
#   'srand',
#   'iswupper',
#   'isdigit',
#   'memmove',
#   'isgraph',
#   'tmpnam',
#   'strncmp',
#   'abort',
#   'vfprintf',
#   'wcscmp',
#   'wcscpy',
#   'setvbuf',
#   'abs',
#   'fread',
#   'strxfrm',
#   'atexit',
#   'asctime',
#   'atof',
#   'strtod',
#   'atoi'],
#  'oleaut32.dll': ['SysAllocString'],
#  'wininet.dll': ['DeleteUrlCacheEntry',
#   'FindFirstUrlCacheEntryA',
#   'FindNextUrlCacheEntryA'],
#  'gdi32.dll': ['GetStockObject',
#   'SetBkColor',
#   'CreateFontA',
#   'GetDeviceCaps',
#   'SelectObject',
#   'DeleteObject',
#   'BitBlt',
#   'GetTextAlign',
#   'EnumFontsW',
#   'ScaleWindowExtEx',
#   'ExtTextOutA',
#   'GetRgnBox',
#   'GetWindowOrgEx',
#   'GetObjectA',
#   'CreateICA',
#   'FillPath',
#   'CreateBitmap',
#   'LPtoDP',
#   'Ellipse',
#   'EndPath',
#   'UpdateColors',
#   'Rectangle',
#   'SetAbortProc',
#   'GetEnhMetaFileHeader',
#   'OffsetWindowOrgEx',
#   'SelectClipRgn',
#   'CopyEnhMetaFileW',
#   'RectVisible',
#   'TextOutA',
#   'RealizePalette',
#   'ChoosePixelFormat',
#   'ColorCorrectPalette',
#   'EngCheckAbort',
#   'GetDIBits',
#   'GetEnhMetaFileBits',
#   'GetMetaFileBitsEx',
#   'GetPaletteEntries',
#   'GetPath',
#   'RestoreDC',
#   'SaveDC',
#   'SelectPalette',
#   'SetDIBitsToDevice',
#   'SetEnhMetaFileBits',
#   'SetMetaFileBitsEx',
#   'SetStretchBltMode',
#   'SetViewportExtEx',
#   'TranslateCharsetInfo',
#   'AddFontResourceA'],
#  'crtdll.dll': ['printf', 'sprintf', 'sscanf', 'vsprintf'],
#  'psapi.dll': ['GetModuleBaseNameW'],
#  'shlwapi.dll': ['PathAppendW',
#   'PathAddBackslashA',
#   'PathFindFileNameA',
#   'PathFileExistsA',
#   'PathAddExtensionA',
#   'PathIsDirectoryA',
#   'PathCombineA',
#   'StrStrNIW',
#   'SHAutoComplete',
#   'PathAppendA',
#   'AssocQueryStringW',
#   'StrCmpW',
#   'PathRemoveFileSpecA',
#   'SHGetValueW',
#   'SHDeleteValueW',
#   'StrCmpNW',
#   'StrChrA',
#   'StrRStrIA'],
#  'ntdll.dll': ['RtlImageNtHeader',
#   'ZwClose',
#   'memset',
#   'strstr',
#   'RtlUnwind',
#   'ZwOpenProcess'],
#  'comsvcs.dll': ['CoEnterServiceDomain',
#   'RecycleSurrogate',
#   'CoCreateActivity'],
#  'crypt32.dll': ['CertOpenStore',
#   'CryptMsgGetParam',
#   'CertGetStoreProperty',
#   'CertCreateCTLContext',
#   'CertDeleteCRLFromStore'],
#  'authz.dll': ['AuthzFreeResourceManager', 'AuthzAddSidsToContext'],
#  'winmm.dll': ['midiOutSetVolume',
#   'mmioOpenA',
#   'mmioWrite',
#   'DrvGetModuleHandle',
#   'waveOutGetErrorTextW',
#   'joySetThreshold',
#   'mmioRead',
#   'waveOutGetDevCapsA',
#   'DefDriverProc',
#   'mmioSetBuffer',
#   'waveOutReset',
#   'waveInGetPosition',
#   'GetDriverModuleHandle',
#   'midiInMessage',
#   'mciGetCreatorTask',
#   'joyGetDevCapsW',
#   'waveInGetErrorTextA',
#   'mixerGetLineControlsW',
#   'PlaySoundW',
#   'timeGetTime'],
#  'mscms.dll': ['GetColorProfileElement',
#   'UninstallColorProfileA',
#   'AssociateColorProfileWithDeviceA',
#   'DisassociateColorProfileFromDeviceW',
#   'GetStandardColorSpaceProfileA',
#   'SetColorProfileHeader',
#   'GetCountColorProfileElements',
#   'InstallColorProfileA',
#   'SetColorProfileElementReference'],
#  'comctl32.dll': ['PropertySheetA',
#   'InitCommonControls',
#   'CreateMappedBitmap',
#   'MenuHelp'],
#  'imm32.dll': ['ImmGetCompositionStringW', 'ImmSetCompositionFontA'],
#  'rsaenh.dll': ['CPEncrypt'],
#  'avifil32.dll': ['AVIStreamGetFrameClose',
#   'AVIStreamRelease',
#   'AVIStreamGetFrame',
#   'AVIStreamOpenFromFileA',
#   'AVIFileInit'],
#  'opengl32.dll': ['glShadeModel', 'glEnable', 'glHint'],
#  'glu32.dll': ['gluQuadricTexture', 'gluQuadricNormals'],
#  'dbghelp.dll': ['SymSetOptions'],
#  'urlmon.dll': ['IsLoggingEnabledW'],
#  'ntdsapi.dll': ['DsBindWithCredA', 'DsBindA'],
#  'winhttp.dll': ['WinHttpCrackUrl',
#   'WinHttpOpenRequest',
#   'WinHttpSendRequest',
#   'WinHttpSetTimeouts',
#   'WinHttpReceiveResponse',
#   'WinHttpQueryDataAvailable',
#   'WinHttpQueryHeaders',
#   'WinHttpCloseHandle'],
#  'cmpbk32.dll': ['PhoneBookFreeFilter',
#   'PhoneBookEnumNumbers',
#   'PhoneBookCopyFilter']}

# %%
a['PhoneBookEnumNumbers']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 a['PhoneBookEnumNumbers']
#
# KeyError: 'PhoneBookEnumNumbers'
